# %%
import os
from dotenv import load_dotenv
from langchain_groq import ChatGroq
from langchain_core.prompts import ChatPromptTemplate
from langchain_core.output_parsers import StrOutputParser

print("✅ Imports loaded!")
# Out:
# ✅ Imports loaded!

# %%
load_dotenv()
api_key = os.getenv('GROQ_API_KEY')
if not api_key:
    print("❌ ERROR: GROQ_API_KEY not found!")
else:
    print(f"✅ API Key loaded: {api_key[:15]}...")
# Out:
# ✅ API Key loaded: gsk_Rt2Np2BcHmO...

# %%
llm = ChatGroq(
    model="llama-3.3-70b-versatile",
    temperature=0.7,
    api_key=api_key
)

print("✅ LLM created!")
# Out:
# ✅ LLM created!

# %%
prompt = ChatPromptTemplate.from_messages([
    ("system", "You are a helpful AI engineering assistant."),
    ("user", "{question}")
])

chain = prompt | llm | StrOutputParser()

print("✅ Chain created!")
# Out:
# ✅ Chain created!

# %%
question = "What is an AI agent and why does it matter?"
print(f"❓ Question: {question}\n")
print("🤖 Thinking...\n")

response = chain.invoke({"question": question})
print(f"💬 Response: {response}\n")

print("✅ Success!")
# Out:
# ❓ Question: What is an AI agent and why does it matter?
#
# 🤖 Thinking...
#
# 💬 Response: An AI agent, also known as an intelligent agent, is a program or system that uses artificial intelligence (AI) and machine learning (ML) to perform tasks autonomously, making decisions and taking actions based on its environment, goals, and constraints. AI agents can be designed to operate in various domains, such as robotics, finance, healthcare, or transportation, and can interact with humans, other agents, or the physical world.
#
# AI agents matter for several reasons:
#
# 1. **Autonomy**: AI agents can operate independently, freeing humans from mundane, repetitive, or dangerous tasks, and enabling them to focus on more complex and creative work.
# 2. **Efficiency**: AI agents can process vast amounts of data, identify patterns, and make decisions faster and more accurately than humans, leading to improved productivity and efficiency.
# 3. **Scalability**: AI agents can be easily replicated and deployed across multiple platforms, making them ideal for large-scale applications, such as customer service, data analysis, or smart home automation.
# 4. **Personalization**: AI agents can learn from individual users' preferences and behaviors, providing personalized recommendations, services, or experiences.
# 5. **Innovation**: AI agents can drive innovation by exploring new possibilities, identifying opportunities, and developing novel solutions to complex problems.
#
# Types of AI agents include:
#
# 1. **Simple reflex agents**: React to the current state of the environment without reasoning or planning.
# 2. **Model-based reflex agents**: Maintain an internal model of the environment and use it to make decisions.
# 3. **Goal-based agents**: Have specific goals and use planning to achieve them.
# 4. **Utility-based agents**: Make decisions based on a utility function that estimates the desirability of each possible action.
# 5. **Learning agents**: Improve their performance over time through machine learning and experience.
#
# Applications of AI agents are diverse and include:
#
# 1. **Virtual assistants**: Siri, Alexa, Google Assistant
# 2. **Chatbots**: Customer service, tech support, and language translation
# 3. **Robotics**: Industrial automation, autonomous vehicles, and drones
# 4. **Finance**: Trading, portfolio management, and risk analysis
# 5. **Healthcare**: Medical diagnosis, personalized medicine, and patient care
#
# In summary, AI agents have the potential to revolutionize various aspects of our lives, from automating routine tasks to driving innovation and improving decision-making. As AI technology continues to advance, we can expect to see more sophisticated and capable AI agents that transform industries and society.
#
# ✅ Success!
